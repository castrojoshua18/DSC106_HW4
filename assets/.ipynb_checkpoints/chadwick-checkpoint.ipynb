# %%
import pandas as pd
df = pd.read_json('cleaned_chadwick.json')
df = df.reset_index().drop(['index', 'main_genre'], axis = 1)

# %%
df.name
# Out:
# 0                     21 Bridges
# 1         Avengers: Infinity War
# 2                    The Express
# 3                       Marshall
# 4     Captain America: Civil War
# 5                      Draft Day
# 6              Avengers: Endgame
# 7                  Black Panther
# 8                  Gods of Egypt
# 9                      Get on Up
# 10                            42
# Name: name, dtype: object

# %%
df['role'] = ['Lead', "Support", "Support", "Lead", "Support", "Support", "Support", "Lead", "Support", "Lead", "Lead"]
df
# Out:
#          date         director                              genres  \
# 0  2019-11-22       Brian Kirk    [Action, Crime, Drama, Thriller]
# 1  2018-04-27    Anthony Russo         [Action, Adventure, Sci-Fi]
# 2  2008-10-10      Gary Fleder           [Biography, Drama, Sport]
# 3  2017-10-13  Reginald Hudlin  [Biography, Crime, Drama, History]
# 4  2016-05-06    Anthony Russo         [Action, Adventure, Sci-Fi]
# 5  2014-04-11     Ivan Reitman                      [Drama, Sport]
# 6  2019-04-26    Anthony Russo  [Action, Adventure, Drama, Sci-Fi]
# 7  2018-02-16     Ryan Coogler         [Action, Adventure, Sci-Fi]
# 8  2016-02-26      Alex Proyas        [Action, Adventure, Fantasy]
# 9  2014-08-01      Tate Taylor           [Biography, Drama, Music]
# 10 2013-04-12  Brian Helgeland           [Biography, Drama, Sport]
#
#                                              keywords  metascore  n_critics  \
# 0   [[nypd, detective, police officer, new york ci...         50         42
# ...

# %%
df.to_json('final_chadwick.json')

# %%
df.sort_values('date')
# Out:
#          date         director                              genres  \
# 2  2008-10-10      Gary Fleder           [Biography, Drama, Sport]
# 10 2013-04-12  Brian Helgeland           [Biography, Drama, Sport]
# 5  2014-04-11     Ivan Reitman                      [Drama, Sport]
# 9  2014-08-01      Tate Taylor           [Biography, Drama, Music]
# 8  2016-02-26      Alex Proyas        [Action, Adventure, Fantasy]
# 4  2016-05-06    Anthony Russo         [Action, Adventure, Sci-Fi]
# 3  2017-10-13  Reginald Hudlin  [Biography, Crime, Drama, History]
# 7  2018-02-16     Ryan Coogler         [Action, Adventure, Sci-Fi]
# 1  2018-04-27    Anthony Russo         [Action, Adventure, Sci-Fi]
# 6  2019-04-26    Anthony Russo  [Action, Adventure, Drama, Sci-Fi]
# 0  2019-11-22       Brian Kirk    [Action, Crime, Drama, Thriller]
#
#                                              keywords  metascore  n_critics  \
# 2   [[john f. kennedy character, african american,...         58         85
# ...

# %%
pd.read_json('final_chadwick.json')
# Out:
#          date         director                              genres  \
# 0  2019-11-22       Brian Kirk    [Action, Crime, Drama, Thriller]
# 1  2018-04-27    Anthony Russo         [Action, Adventure, Sci-Fi]
# 10 2013-04-12  Brian Helgeland           [Biography, Drama, Sport]
# 2  2008-10-10      Gary Fleder           [Biography, Drama, Sport]
# 3  2017-10-13  Reginald Hudlin  [Biography, Crime, Drama, History]
# 4  2016-05-06    Anthony Russo         [Action, Adventure, Sci-Fi]
# 5  2014-04-11     Ivan Reitman                      [Drama, Sport]
# 6  2019-04-26    Anthony Russo  [Action, Adventure, Drama, Sci-Fi]
# 7  2018-02-16     Ryan Coogler         [Action, Adventure, Sci-Fi]
# 8  2016-02-26      Alex Proyas        [Action, Adventure, Fantasy]
# 9  2014-08-01      Tate Taylor           [Biography, Drama, Music]
#
#                                              keywords  metascore  n_critics  \
# 0   [[nypd, detective, police officer, new york ci...         50         42
# ...
